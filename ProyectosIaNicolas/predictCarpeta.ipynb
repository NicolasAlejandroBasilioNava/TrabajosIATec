# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import os

model_path = './clasFlores.h5py'
model = tf.keras.models.load_model(model_path)

target_size = (32, 32)
folder_path = "../DATASETS/Pruebas_Flores/"
class_labels = ["cuna", "girasol", "jacinto",  "oreja", "tulipan"]  # Actualiza con tus etiquetas

# Obtén la lista de archivos en la carpeta
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

for image_file in image_files:
    # Construye la ruta completa de la imagen
    image_path = os.path.join(folder_path, image_file)

    # Carga y procesa la imagen
    img = image.load_img(image_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    # Realiza la predicción
    predictions = model.predict(img_array)

    # Obtiene la etiqueta predicha
    predicted_class_indices = np.argmax(predictions, axis=1)
    predicted_label = class_labels[predicted_class_indices[0]]

    # Muestra la imagen y la predicción
    plt.imshow(img)
    plt.title(f"Predicted class: {predicted_label}")
    plt.show()

    print(f"Image: {image_file}, Predicted class: {predicted_label}")
# Out:
# 1/1 [==============================] - 0s 192ms/step
# Image: Cuna1.png, Predicted class: cuna
# 1/1 [==============================] - 0s 50ms/step
# Image: Cuna2.jpg, Predicted class: cuna
# 1/1 [==============================] - 0s 59ms/step
# Image: Cuna3.jpg, Predicted class: cuna
# 1/1 [==============================] - 0s 48ms/step
# Image: Cuna4.png, Predicted class: oreja
# 1/1 [==============================] - 0s 48ms/step
# Image: Cuna5.png, Predicted class: cuna
# 1/1 [==============================] - 0s 61ms/step
# Image: Gira1.png, Predicted class: girasol
# 1/1 [==============================] - 0s 65ms/step
# Image: Gira2.png, Predicted class: girasol
# 1/1 [==============================] - 0s 60ms/step
# Image: Gira3.png, Predicted class: girasol
# 1/1 [==============================] - 0s 41ms/step
# Image: Gira4.jpg, Predicted class: girasol
# 1/1 [==============================] - 0s 44ms/step
# Image: Jaci1.jpg, Predicted class: tulipan
# ...
